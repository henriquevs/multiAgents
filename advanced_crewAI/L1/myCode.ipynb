# %%
# Warning control
import warnings
warnings.filterwarnings('ignore')

# Load environment variables
from helper import load_env
load_env()

import os
import yaml
from crewai import Agent, Task, Crew

# %%
os.environ['OPENAI_MODEL_NAME'] = 'gpt-4o-mini'

# %%
# Define file paths for YAML configurations
files = {
    'agents': 'config/agents.yaml',
    'tasks': 'config/tasks.yaml'
}

# Load configurations from YAML files
configs = {}
for config_type, file_path in files.items():
    with open(file_path, 'r') as file:
        configs[config_type] = yaml.safe_load(file)

# Assign loaded configurations to specific variables
agents_config = configs['agents']
tasks_config = configs['tasks']

# %%
from typing import List
from pydantic import BaseModel, Field

class TaskEstimate(BaseModel):
    task_name: str = Field(..., description="Name of the task")
    estimated_time_hours: float = Field(..., description="Estimated time to complete the task in hours")
    required_resources: List[str] = Field(..., description="List of resources required to complete the task")

class Milestone(BaseModel):
    milestone_name: str = Field(..., description="Name of the milestone")
    tasks: List[str] = Field(..., description="List of task IDs associated with this milestone")

class ProjectPlan(BaseModel):
    tasks: List[TaskEstimate] = Field(..., description="List of tasks with their estimates")
    milestones: List[Milestone] = Field(..., description="List of project milestones")

# %%
# Creating Agents
project_planning_agent = Agent(
  config=agents_config['project_planning_agent']
)

estimation_agent = Agent(
  config=agents_config['estimation_agent']
)

resource_allocation_agent = Agent(
  config=agents_config['resource_allocation_agent']
)

# Creating Tasks
task_breakdown = Task(
  config=tasks_config['task_breakdown'],
  agent=project_planning_agent
)

time_resource_estimation = Task(
  config=tasks_config['time_resource_estimation'],
  agent=estimation_agent
)

resource_allocation = Task(
  config=tasks_config['resource_allocation'],
  agent=resource_allocation_agent,
  output_pydantic=ProjectPlan # This is the structured output we want
)

# Creating Crew
crew = Crew(
  agents=[
    project_planning_agent,
    estimation_agent,
    resource_allocation_agent
  ],
  tasks=[
    task_breakdown,
    time_resource_estimation,
    resource_allocation
  ],
  verbose=True
)

# %%
from IPython.display import display, Markdown

project = 'Website'
industry = 'Technology'
project_objectives = 'Create a website for a small business'
team_members = """
- John Doe (Project Manager)
- Jane Doe (Software Engineer)
- Bob Smith (Designer)
- Alice Johnson (QA Engineer)
- Tom Brown (QA Engineer)
"""
project_requirements = """
- Create a responsive design that works well on desktop and mobile devices
- Implement a modern, visually appealing user interface with a clean look
- Develop a user-friendly navigation system with intuitive menu structure
- Include an "About Us" page highlighting the company's history and values
- Design a "Services" page showcasing the business's offerings with descriptions
- Create a "Contact Us" page with a form and integrated map for communication
- Implement a blog section for sharing industry news and company updates
- Ensure fast loading times and optimize for search engines (SEO)
- Integrate social media links and sharing capabilities
- Include a testimonials section to showcase customer feedback and build trust
"""

# Format the dictionary as Markdown for a better display in Jupyter Lab
formatted_output = f"""
**Project Type:** {project}

**Project Objectives:** {project_objectives}

**Industry:** {industry}

**Team Members:**
{team_members}
**Project Requirements:**
{project_requirements}
"""
# Display the formatted output as Markdown
display(Markdown(formatted_output))
# Out:
# **Project Type:** Website
#
# **Project Objectives:** Create a website for a small business
#
# **Industry:** Technology
#
# **Team Members:**
#
# - John Doe (Project Manager)
# - Jane Doe (Software Engineer)
# - Bob Smith (Designer)
# - Alice Johnson (QA Engineer)
# - Tom Brown (QA Engineer)
#
# **Project Requirements:**
#
# - Create a responsive design that works well on desktop and mobile devices
# - Implement a modern, visually appealing user interface with a clean look
# - Develop a user-friendly navigation system with intuitive menu structure
# - Include an "About Us" page highlighting the company's history and values
# - Design a "Services" page showcasing the business's offerings with descriptions
# - Create a "Contact Us" page with a form and integrated map for communication
# - Implement a blog section for sharing industry news and company updates
# - Ensure fast loading times and optimize for search engines (SEO)
# - Integrate social media links and sharing capabilities
# - Include a testimonials section to showcase customer feedback and build trust

# %%
# The given Python dictionary
inputs = {
  'project_type': project,
  'project_objectives': project_objectives,
  'industry': industry,
  'team_members': team_members,
  'project_requirements': project_requirements
}

# Run the crew
result = crew.kickoff(
  inputs=inputs
)
# Out:
# # Agent: The Ultimate Project Planner
# ## Task: Carefully analyze the project_requirements for the Website project and break them down into individual tasks. Define each task's scope in detail, set achievable timelines, and ensure that all dependencies are accounted for:
#
# - Create a responsive design that works well on desktop and mobile devices
# - Implement a modern, visually appealing user interface with a clean look
# - Develop a user-friendly navigation system with intuitive menu structure
# - Include an "About Us" page highlighting the company's history and values
# - Design a "Services" page showcasing the business's offerings with descriptions
# - Create a "Contact Us" page with a form and integrated map for communication
# - Implement a blog section for sharing industry news and company updates
# - Ensure fast loading times and optimize for search engines (SEO)
# - Integrate social media links and sharing capabilities
# - Include a testimonials section to showcase customer feedback and build trust
#
#
# Team members:
#
# - John Doe (Project Manager)
# - Jane Doe (Software Engineer)
# - Bob Smith (Designer)
# - Alice Johnson (QA Engineer)
# - Tom Brown (QA Engineer)
#
#
#
#
# # Agent: The Ultimate Project Planner
# ## Final Answer:
# ### Comprehensive Breakdown of Website Project Tasks
#
# **Project Overview:** Create a website for a small business with an emphasis on responsiveness, user experience, and effective communication of company values and offerings.
#
# ---
#
# ### Task List with Detailed Descriptions, Timelines, Dependencies, and Deliverables
#
# 1. **Create a Responsive Design**
#    - **Description:** Develop a layout that adapts fluidly to desktop, tablet, and mobile interfaces, ensuring a seamless user experience across devices.
#    - **Timeline:** 2 weeks
#    - **Dependencies:** None
#    - **Deliverables:** Design mockups and prototypes for various screen sizes.
#
# 2. **Implement a Modern User Interface**
#    - **Description:** Design and implement a visually appealing interface with a minimalist aesthetic that enhances usability.
#    - **Timeline:** 3 weeks
#    - **Dependencies:** Completion of responsive design
#    - **Deliverables:** Finalized UI designs with graphical assets.
#
# 3. **Develop User-Friendly Navigation System**
#    - **Description:** Create an intuitive menu structure that allows users to easily access different sections of the website.
#    - **Timeline:** 1 week
#    - **Dependencies:** Modern UI implementation
#    - **Deliverables:** Functional website navigation panel.
#
# 4. **Create "About Us" Page**
#    - **Description:** Develop content that highlights the company’s history, mission, and core values, incorporating visuals and engaging text.
#    - **Timeline:** 1 week
#    - **Dependencies:** None
#    - **Deliverables:** Completed "About Us" page ready for integration.
#
# 5. **Design "Services" Page**
#    - **Description:** Showcase the business's services, complete with detailed descriptions and related images to highlight offerings.
#    - **Timeline:** 1 week
#    - **Dependencies:** None
#    - **Deliverables:** Completed "Services" page.
#
# 6. **Create "Contact Us" Page**
#    - **Description:** Implement a contact form for inquiries and integrate a map for location services to facilitate easy communication.
#    - **Timeline:** 1 week
#    - **Dependencies:** None
#    - **Deliverables:** Fully functional "Contact Us" page.
#
# 7. **Implement Blog Section**
#    - **Description:** Set up a blog capable of sharing industry news, insights, and updates, allowing for dynamic content generation.
#    - **Timeline:** 2 weeks
#    - **Dependencies:** Responsive design
#    - **Deliverables:** Functional blog section with an easy-to-use interface for posting.
#
# 8. **Optimize for Fast Loading Times and SEO**
#    - **Description:** Ensure the website loads quickly and is optimized for search engines through appropriate tags and keywords.
#    - **Timeline:** 1 week
#    - **Dependencies:** Completion of all pages
#    - **Deliverables:** SEO report and page performance metrics.
#
# 9. **Integrate Social Media Links**
#    - **Description:** Add links to the company’s social media profiles and enable content sharing capabilities for wider reach.
#    - **Timeline:** 1 week
#    - **Dependencies:** None
#    - **Deliverables:** Embedded social media icons and share buttons.
#
# 10. **Include Testimonials Section**
#     - **Description:** Collect and showcase customer feedback and reviews to build credibility and trust among potential clients.
#     - **Timeline:** 1 week
#     - **Dependencies:** None
#     - **Deliverables:** Completed testimonials page with design integration.
#
# ---
#
# ### Project Timeline Visualization (Gantt Chart)
#
# | Task                              | Week 1 | Week 2 | Week 3 | Week 4 | Week 5 | Week 6 |
# |-----------------------------------|--------|--------|--------|--------|--------|--------|
# | Create Responsive Design          |   X    |   X    |        |        |        |        |
# | Implement Modern UI               |        |   X    |   X    |        |        |        |
# | Develop User-Friendly Navigation   |        |        |   X    |        |        |        |
# | Create "About Us" Page           |        |        |   X    |        |        |        |
# | Design "Services" Page           |        |        |   X    |        |        |        |
# | Create "Contact Us" Page         |        |        |   X    |        |        |        |
# | Implement Blog Section            |        |        |        |   X    |   X    |        |
# | Optimize for Fast Loading & SEO   |        |        |        |        |   X    |        |
# | Integrate Social Media Links      |        |        |        |        |        |   X    |
# | Include Testimonials Section       |        |        |        |        |        |   X    |
#
# ### Team Members Assigned
# - **John Doe (Project Manager)**: Overseeing project execution and ensuring deadlines are met.
# - **Jane Doe (Software Engineer)**: Responsible for coding and implementing various web functionalities.
# - **Bob Smith (Designer)**: Developing the visual design elements and user interface.
# - **Alice Johnson (QA Engineer)**: Conducting quality assurance testing on each component.
# - **Tom Brown (QA Engineer)**: Assisting in QA and ensuring all features work correctly.
#
# This detailed breakdown ensures that every aspect of the website project is addressed, keeping the team aligned and focused on delivering a highly functional and visually appealing website. Each task is chronologically structured to maximize productivity and streamline the project flow.
#
#
# # Agent: Expert Estimation Analyst
# ## Task: Thoroughly evaluate each task in the Website project to estimate the time, resources, and effort required. Use historical data, task complexity, and available resources to provide a realistic estimation for each task.
#
#
#
# # Agent: Expert Estimation Analyst
# ## Final Answer:
# ### Estimation Report for Website Project
#
# #### Project Overview:
# The goal of this project is to develop a responsive website for a small business that highlights its values and services effectively, providing a seamless user experience across all devices.
#
# ### Detailed Estimations for Each Task
#
# 1. **Create a Responsive Design**
#    - **Time Required:** 2 weeks
#    - **Resources Needed:**
#      - Designer: 1 (Bob Smith)
#      - Tools: Design software (Adobe XD, Figma)
#    - **Effort:** 80 hours
#    - **Deliverables:** Design mockups and prototypes for various screen sizes.
#    - **Risks:** Limited device variety for testing could lead to oversights in responsiveness on less common devices.
#
# 2. **Implement a Modern User Interface**
#    - **Time Required:** 3 weeks
#    - **Resources Needed:**
#      - Designer: 1 (Bob Smith)
#      - Software Engineer: 1 (Jane Doe)
#    - **Effort:** 120 hours
#    - **Deliverables:** Finalized UI designs with graphical assets.
#    - **Risks:** Misalignment between design and implementation due to different interpretations. Regular reviews needed.
#
# 3. **Develop User-Friendly Navigation System**
#    - **Time Required:** 1 week
#    - **Resources Needed:**
#      - Software Engineer: 1 (Jane Doe)
#    - **Effort:** 40 hours
#    - **Deliverables:** Functional website navigation panel.
#    - **Risks:** Complexity in creating adaptive navigation for various screen sizes could lead to extended development time.
#
# 4. **Create "About Us" Page**
#    - **Time Required:** 1 week
#    - **Resources Needed:**
#      - Content Writer: 1 (consider hiring if not available)
#      - Designer: 1 (Bob Smith)
#    - **Effort:** 30 hours
#    - **Deliverables:** Completed "About Us" page ready for integration.
#    - **Risks:** Delays in content approval may lead to bottlenecks. Regular communication is key.
#
# 5. **Design "Services" Page**
#    - **Time Required:** 1 week
#    - **Resources Needed:**
#      - Designer: 1 (Bob Smith)
#    - **Effort:** 30 hours
#    - **Deliverables:** Completed "Services" page.
#    - **Risks:** Insufficient details on services can lead to incomplete page functionality.
#
# 6. **Create "Contact Us" Page**
#    - **Time Required:** 1 week
#    - **Resources Needed:**
#      - Software Engineer: 1 (Jane Doe)
#    - **Effort:** 40 hours
#    - **Deliverables:** Fully functional "Contact Us" page.
#    - **Risks:** Technical issues with integrating third-party services (e.g., map features) could cause delays.
#
# 7. **Implement Blog Section**
#    - **Time Required:** 2 weeks
#    - **Resources Needed:**
#      - Software Engineer: 1 (Jane Doe)
#    - **Effort:** 80 hours
#    - **Deliverables:** Functional blog section with interface for posting.
#    - **Risks:** Content management system integration challenges could hinder functionality.
#
# 8. **Optimize for Fast Loading Times and SEO**
#    - **Time Required:** 1 week
#    - **Resources Needed:**
#      - Software Engineer: 1 (Jane Doe)
#    - **Effort:** 30 hours
#    - **Deliverables:** SEO report and page performance metrics.
#    - **Risks:** SEO guidelines constantly change; adherence to latest standards is paramount but may require additional effort.
#
# 9. **Integrate Social Media Links**
#    - **Time Required:** 1 week
#    - **Resources Needed:**
#      - Software Engineer: 1 (Jane Doe)
#    - **Effort:** 20 hours
#    - **Deliverables:** Embedded social media icons and share buttons.
#    - **Risks:** Continuous changes or updates from social media platforms might require redesigns.
#
# 10. **Include Testimonials Section**
#     - **Time Required:** 1 week
#     - **Resources Needed:**
#       - Content Writer: 1
#       - Designer: 1 (Bob Smith)
#     - **Effort:** 30 hours
#     - **Deliverables:** Completed testimonials page with design integration.
#     - **Risks:** Gathering sufficient testimonials within the timeframe may be challenging.
#
# ### Summary of Risks and Uncertainties
# - Dependencies create potential bottlenecks; tasks are interconnected, requiring careful management.
# - Resource availability can cause delays — redundancy plans may be needed, especially for critical tasks.
# - Potential for scope creep; additional features could lead to increased timelines.
# - Regular communication with stakeholders is vital to avoid misunderstandings about expectations and deliverables.
#
# ### Summary of Total Estimates
# - **Overall Timeline:** 14 weeks (accounting for overlapping tasks)
# - **Total Resources:** 3 team members primarily (Project Manager, Designer, Software Engineer)
# - **Estimated Total Effort:** 460 hours
#
# This estimation provides a comprehensive roadmap to ensuring the website project is completed on time and within budget while mitigating risks effectively. Continuous assessment and adaptation throughout the project timeframe will enhance the possibility of project success.
#
#
# # Agent: Resource Allocation Strategist
# ## Task: Strategically allocate tasks for the Website project to team members based on their skills, availability, and current workload. Ensure that each task is assigned to the most suitable team member and that the workload is evenly distributed.
#
# Team members:
#
# - John Doe (Project Manager)
# - Jane Doe (Software Engineer)
# - Bob Smith (Designer)
# - Alice Johnson (QA Engineer)
# - Tom Brown (QA Engineer)
#
#
#
#
# # Agent: Resource Allocation Strategist
# ## Final Answer:
# ### Resource Allocation Chart for Website Project
#
# | Task                                      | Team Member       | Start Date | End Date   | Hours Required |
# |-------------------------------------------|-------------------|------------|------------|----------------|
# | Create a Responsive Design                | Bob Smith (Designer)    | Week 1     | Week 3     | 80             |
# | Implement a Modern User Interface         | Bob Smith (Designer) & Jane Doe (Software Engineer) | Week 3     | Week 6     | 120            |
# | Develop User-Friendly Navigation System    | Jane Doe (Software Engineer) | Week 6     | Week 7     | 40             |
# | Create "About Us" Page                   | Bob Smith (Designer) & Content Writer (TBD) | Week 6     | Week 7     | 30             |
# | Design "Services" Page                    | Bob Smith (Designer) | Week 7     | Week 8     | 30             |
# | Create "Contact Us" Page                  | Jane Doe (Software Engineer) | Week 7     | Week 8     | 40             |
# | Implement Blog Section                     | Jane Doe (Software Engineer) | Week 8     | Week 10    | 80             |
# | Optimize for Fast Loading Times and SEO   | Jane Doe (Software Engineer) | Week 10    | Week 11    | 30             |
# | Integrate Social Media Links               | Jane Doe (Software Engineer) | Week 11    | Week 12    | 20             |
# | Include Testimonials Section               | Bob Smith (Designer) & Content Writer (TBD) | Week 11    | Week 12    | 30             |
#
# ### Summary of Rationale Behind Allocations:
#
# 1. **Create a Responsive Design**: Assigned to Bob Smith as the sole designer to focus on creating the foundational design mockups, given his expertise in design tools and experience.
#
# 2. **Implement a Modern User Interface**: Both Bob Smith and Jane Doe are involved in this task to ensure that design and technical implementation are aligned closely, reducing interpretation issues between design and development.
#
# 3. **Develop User-Friendly Navigation System**: Assigned solely to Jane Doe, who is available and skilled in front-end development, allowing for a concentrated effort without being conflicting with other tasks.
#
# 4. **Create "About Us" Page**: This requires collaboration between Bob Smith and an anticipated external Content Writer, ensuring that the design aligns well with the content; it's crucial to initiate this task early to avoid bottlenecks due to content approval.
#
# 5. **Design "Services" Page**: Allocated to Bob Smith since it's a design-focused task, and he can manage this within his workload after the initial design phase is complete.
#
# 6. **Create "Contact Us" Page**: Jane Doe takes on this task as she is well-positioned to implement the functionality required for the page while juggling other tasks.
#
# 7. **Implement Blog Section**: A significant task that will be handled by Jane Doe alone; it utilizes her technical skills to ensure a seamless integration.
#
# 8. **Optimize for Fast Loading Times and SEO**: This task is designated to Jane Doe as it builds upon her previous work and demands an understanding of both coding and SEO strategies, minimizing the learning curve.
#
# 9. **Integrate Social Media Links**: Assigned to Jane Doe, this task follows the blog section and is relatively straightforward, fitting into her established workflow.
#
# 10. **Include Testimonials Section**: Collaboratively designed by Bob Smith and a Content Writer (TBD); it merges aesthetic design with content collection—which must be handled concurrently to ensure timelines are kept.
#
# The chart is structured to ensure that no individual is overburdened while also taking advantage of their skill sets. The general timeline of 14 weeks accommodates the overlapping nature of tasks and anticipates collaboration requirements effectively, fostering a balance between productivity and project success. Regular check-ins are recommended to ensure dependencies are addressed, particularly for tasks reliant on external content.

# %%
import pandas as pd

costs = 0.150 * (crew.usage_metrics.prompt_tokens + crew.usage_metrics.completion_tokens) / 1_000_000
print(f"Total costs: ${costs:.4f}")

# Convert UsageMetrics instance to a DataFrame
df_usage_metrics = pd.DataFrame([crew.usage_metrics.dict()])
df_usage_metrics
# Out:
# Total costs: $0.0027
#    total_tokens  prompt_tokens  completion_tokens  successful_requests
# 0         17690          10808               6882                    9

# %%
result.pydantic.dict()
# Out:
# {'tasks': [{'task_name': 'Create a Responsive Design',
#    'estimated_time_hours': 80.0,
#    'required_resources': ['Bob Smith (Designer)']},
#   {'task_name': 'Implement a Modern User Interface',
#    'estimated_time_hours': 120.0,
#    'required_resources': ['Bob Smith (Designer)',
#     'Jane Doe (Software Engineer)']},
#   {'task_name': 'Develop User-Friendly Navigation System',
#    'estimated_time_hours': 40.0,
#    'required_resources': ['Jane Doe (Software Engineer)']},
#   {'task_name': "Create 'About Us' Page",
#    'estimated_time_hours': 30.0,
#    'required_resources': ['Bob Smith (Designer)', 'Content Writer (TBD)']},
#   {'task_name': "Design 'Services' Page",
#    'estimated_time_hours': 30.0,
#    'required_resources': ['Bob Smith (Designer)']},
#   {'task_name': "Create 'Contact Us' Page",
#    'estimated_time_hours': 40.0,
#    'required_resources': ['Jane Doe (Software Engineer)']},
#   {'task_name': 'Implement Blog Section',
#    'estimated_time_hours': 80.0,
#    'required_resources': ['Jane Doe (Software Engineer)']},
#   {'task_name': 'Optimize for Fast Loading Times and SEO',
#    'estimated_time_hours': 30.0,
#    'required_resources': ['Jane Doe (Software Engineer)']},
#   {'task_name': 'Integrate Social Media Links',
#    'estimated_time_hours': 20.0,
#    'required_resources': ['Jane Doe (Software Engineer)']},
#   {'task_name': 'Include Testimonials Section',
#    'estimated_time_hours': 30.0,
#    'required_resources': ['Bob Smith (Designer)', 'Content Writer (TBD)']}],
#  'milestones': [{'milestone_name': 'Design Completion',
#    'tasks': ['Create a Responsive Design',
#     'Implement a Modern User Interface',
#     "Design 'Services' Page",
#     "Create 'About Us' Page",
#     'Include Testimonials Section']},
#   {'milestone_name': 'Development Completion',
#    'tasks': ['Develop User-Friendly Navigation System',
#     "Create 'Contact Us' Page",
#     'Implement Blog Section',
#     'Optimize for Fast Loading Times and SEO',
#     'Integrate Social Media Links']},
#   {'milestone_name': 'Project Launch',
#    'tasks': ['Design Completion', 'Development Completion']}]}

# %%
tasks = result.pydantic.dict()['tasks']
df_tasks = pd.DataFrame(tasks)

# Display the DataFrame as an HTML table
df_tasks.style.set_table_attributes('border="1"').set_caption("Task Details").set_table_styles(
    [{'selector': 'th, td', 'props': [('font-size', '120%')]}]
)
# Out:
# <style type="text/css">
# #T_2b592 th {
#   font-size: 120%;
# }
# #T_2b592  td {
#   font-size: 120%;
# }
# </style>
# <table id="T_2b592" border="1">
#   <caption>Task Details</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2b592_level0_col0" class="col_heading level0 col0" >task_name</th>
#       <th id="T_2b592_level0_col1" class="col_heading level0 col1" >estimated_time_hours</th>
#       <th id="T_2b592_level0_col2" class="col_heading level0 col2" >required_resources</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2b592_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_2b592_row0_col0" class="data row0 col0" >Create a Responsive Design</td>
#       <td id="T_2b592_row0_col1" class="data row0 col1" >80.000000</td>
#       <td id="T_2b592_row0_col2" class="data row0 col2" >['Bob Smith (Designer)']</td>
#     </tr>
#     <tr>
#       <th id="T_2b592_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_2b592_row1_col0" class="data row1 col0" >Implement a Modern User Interface</td>
#       <td id="T_2b592_row1_col1" class="data row1 col1" >120.000000</td>
#       <td id="T_2b592_row1_col2" class="data row1 col2" >['Bob Smith (Designer)', 'Jane Doe (Software Engineer)']</td>
#     </tr>
#     <tr>
#       <th id="T_2b592_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_2b592_row2_col0" class="data row2 col0" >Develop User-Friendly Navigation System</td>
#       <td id="T_2b592_row2_col1" class="data row2 col1" >40.000000</td>
#       <td id="T_2b592_row2_col2" class="data row2 col2" >['Jane Doe (Software Engineer)']</td>
#     </tr>
#     <tr>
#       <th id="T_2b592_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_2b592_row3_col0" class="data row3 col0" >Create 'About Us' Page</td>
#       <td id="T_2b592_row3_col1" class="data row3 col1" >30.000000</td>
#       <td id="T_2b592_row3_col2" class="data row3 col2" >['Bob Smith (Designer)', 'Content Writer (TBD)']</td>
#     </tr>
#     <tr>
#       <th id="T_2b592_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_2b592_row4_col0" class="data row4 col0" >Design 'Services' Page</td>
#       <td id="T_2b592_row4_col1" class="data row4 col1" >30.000000</td>
#       <td id="T_2b592_row4_col2" class="data row4 col2" >['Bob Smith (Designer)']</td>
#     </tr>
#     <tr>
#       <th id="T_2b592_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_2b592_row5_col0" class="data row5 col0" >Create 'Contact Us' Page</td>
#       <td id="T_2b592_row5_col1" class="data row5 col1" >40.000000</td>
#       <td id="T_2b592_row5_col2" class="data row5 col2" >['Jane Doe (Software Engineer)']</td>
#     </tr>
#     <tr>
#       <th id="T_2b592_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_2b592_row6_col0" class="data row6 col0" >Implement Blog Section</td>
#       <td id="T_2b592_row6_col1" class="data row6 col1" >80.000000</td>
#       <td id="T_2b592_row6_col2" class="data row6 col2" >['Jane Doe (Software Engineer)']</td>
#     </tr>
#     <tr>
#       <th id="T_2b592_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_2b592_row7_col0" class="data row7 col0" >Optimize for Fast Loading Times and SEO</td>
#       <td id="T_2b592_row7_col1" class="data row7 col1" >30.000000</td>
#       <td id="T_2b592_row7_col2" class="data row7 col2" >['Jane Doe (Software Engineer)']</td>
#     </tr>
#     <tr>
#       <th id="T_2b592_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_2b592_row8_col0" class="data row8 col0" >Integrate Social Media Links</td>
#       <td id="T_2b592_row8_col1" class="data row8 col1" >20.000000</td>
#       <td id="T_2b592_row8_col2" class="data row8 col2" >['Jane Doe (Software Engineer)']</td>
#     </tr>
#     <tr>
#       <th id="T_2b592_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_2b592_row9_col0" class="data row9 col0" >Include Testimonials Section</td>
#       <td id="T_2b592_row9_col1" class="data row9 col1" >30.000000</td>
#       <td id="T_2b592_row9_col2" class="data row9 col2" >['Bob Smith (Designer)', 'Content Writer (TBD)']</td>
#     </tr>
#   </tbody>
# </table>

# %%
milestones = result.pydantic.dict()['milestones']
df_milestones = pd.DataFrame(milestones)

# Display the DataFrame as an HTML table
df_milestones.style.set_table_attributes('border="1"').set_caption("Task Details").set_table_styles(
    [{'selector': 'th, td', 'props': [('font-size', '120%')]}]
)
# Out:
# <style type="text/css">
# #T_3b4ee th {
#   font-size: 120%;
# }
# #T_3b4ee  td {
#   font-size: 120%;
# }
# </style>
# <table id="T_3b4ee" border="1">
#   <caption>Task Details</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3b4ee_level0_col0" class="col_heading level0 col0" >milestone_name</th>
#       <th id="T_3b4ee_level0_col1" class="col_heading level0 col1" >tasks</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3b4ee_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_3b4ee_row0_col0" class="data row0 col0" >Design Completion</td>
#       <td id="T_3b4ee_row0_col1" class="data row0 col1" >['Create a Responsive Design', 'Implement a Modern User Interface', "Design 'Services' Page", "Create 'About Us' Page", 'Include Testimonials Section']</td>
#     </tr>
#     <tr>
#       <th id="T_3b4ee_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_3b4ee_row1_col0" class="data row1 col0" >Development Completion</td>
#       <td id="T_3b4ee_row1_col1" class="data row1 col1" >['Develop User-Friendly Navigation System', "Create 'Contact Us' Page", 'Implement Blog Section', 'Optimize for Fast Loading Times and SEO', 'Integrate Social Media Links']</td>
#     </tr>
#     <tr>
#       <th id="T_3b4ee_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_3b4ee_row2_col0" class="data row2 col0" >Project Launch</td>
#       <td id="T_3b4ee_row2_col1" class="data row2 col1" >['Design Completion', 'Development Completion']</td>
#     </tr>
#   </tbody>
# </table>
